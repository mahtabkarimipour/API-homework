# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
citydata = pd.read_csv('dataa.csv')
citydata.head()
# Out:
#                  Name  Latitude  Temperature  WindSpeed  Cloudiness  Humidity
# 0           Lozuvatka     48.06       266.15        7.0          90        79
# 1           Pontaumur     45.87       273.15        1.0          90        96
# 2            Tateyama     34.98       278.15        4.6          75        52
# 3        Bady Bassitt    -20.92       301.15        2.1          40        51
# 4  Marietta-Alderwood     48.79       283.44        2.6           1        61

# %%
plt.scatter(citydata["Latitude"], citydata["Temperature"], marker="o", facecolors="red", edgecolors="black",
             alpha=0.75)
plt.title("city Latitude vs Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
# Out:
# Text(0,0.5,'Temperature')

# %%
plt.scatter(citydata["Latitude"], citydata["WindSpeed"], marker="o", facecolors="red", edgecolors="black",
             alpha=0.75)
plt.title("city Latitude vs WindSpeed")
plt.xlabel("Latitude")
plt.ylabel("WindSpeed")
# Out:
# Text(0,0.5,'WindSpeed')

# %%
plt.scatter(citydata["Latitude"], citydata["Cloudiness"], marker="o", facecolors="red", edgecolors="black",
             alpha=0.75)
plt.title("city Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
# Out:
# Text(0,0.5,'Cloudiness')

# %%
plt.scatter(citydata["Latitude"], citydata["Humidity"], marker="o", facecolors="red", edgecolors="black",
             alpha=0.75)
plt.title("city Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
# Out:
# Text(0,0.5,'Humidity')
